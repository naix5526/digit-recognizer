# %%
### Load Dataset
import pandas as pd 
from sklearn.utils import shuffle

data = pd.read_csv('dataset.csv')
data = shuffle(data)
data
# Out:
#      label  pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  \
# 569      5       0       0       0       0       0       0       0       0
# 698      6       0       0       0       0       0       0       0       0
# 704      7       0       0       0       0       0       0       0       0
# 924      9       0       0       0       0       0       0       0       0
# 921      9       0       0       0       0       0       0       0       0
# ..     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 706      7       0       0       0       0       0       0       0       0
# 90       0       0       0       0       0       0       0       0       0
# 979      9       0       0       0       0       0       0       0       0
# 705      7       0       0       0       0       0       0       0       0
# 890      8       0       0       0       0       0       0       0       0
#
#      pixel8  ...  pixel774  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 569       0  ...         0         0         0         0         0         0
# 698       0  ...         0         0         0         0         0         0
# 704       0  ...         0         0         0         0         0         0
# 924       0  ...         0         0         0         0         0         0
# 921       0  ...         0         0         0         0         0         0
# ..      ...  ...       ...       ...       ...       ...       ...       ...
# 706       0  ...         0         0         0         0         0         0
# 90        0  ...         0         0         0         0         0         0
# 979       0  ...         0         0         0         0         0         0
# 705       0  ...         0         0         0         0         0         0
# 890       0  ...         0         0         0         0         0         0
#
#      pixel780  pixel781  pixel782  pixel783
# 569         0         0         0         0
# 698         0         0         0         0
# 704         0         0         0         0
# 924         0         0         0         0
# 921         0         0         0         0
# ..        ...       ...       ...       ...
# 706         0         0         0         0
# 90          0         0         0         0
# 979         0         0         0         0
# 705         0         0         0         0
# 890         0         0         0         0
#
# [1000 rows x 785 columns]

# %%
### Splitting the dataset
X = data.drop(["label"],axis =1 )

# %%
Y = data["label"]

# %%
### Train-Test split
from sklearn.model_selection import train_test_split
train_x, text_x, train_y, test_y = train_test_split(X,Y,test_size=0.2)

# %%
## Fit the model using SVC
